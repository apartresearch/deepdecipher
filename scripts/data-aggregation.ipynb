# %%
# Extract data from az://openaipublic/neuron-explainer/data/collated-activations/1/1.json

import json
import pandas as pd
import numpy as np
import os
import glob
import re
import sys
import time
import datetime
import logging
import argparse
import subprocess

# %% [markdown]
# # Download GPT-4 explanations dataset
#
# Taken straight from [the API documentation](https://github.com/openai/automated-interpretability), this code downloads all files for the neurons, combines them, and compresses them.

# %%
# Download data from az://openaipublic/neuron-explainer/data/collated-activations/1/1.json
# to local directory

# Set up GPT-2 XL tokenization
from transformers import GPT2Tokenizer, GPT2Model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-xl', timeout = 1000)

# Set up workers for parallel processing
from joblib import Parallel, delayed
import multiprocessing as mp
num_cores = mp.cpu_count()
print(f"Number of cores: {num_cores}")

# Set up logging
import logging
logging.getLogger().setLevel(logging.CRITICAL)

def download_data(layer, neuron, dir="../data"):
    """
    Download data from Azure OpenAI blob storage to local directory.
    """

    # Download data from Azure blob storage
    os.makedirs(dir, exist_ok=True)
    print(layer, neuron)
    cmd = f"azcopy copy \"https://openaipublic.blob.core.windows.net/neuron-explainer/data/collated-activations/{layer}/{neuron}.json\" \"{dir}\""
    subprocess.call(cmd, shell=True)

def data_processing(data_dir, tokenizer = tokenizer, data_format = "neuron-viewer"):
    """
    Process data from neuron-viewer json format to a more efficient token-encoded format.
    """    
    
    # Read json data
    if data_format == "neuron-viewer":
        with open(data_dir) as f:
            data = json.load(f)
            for sample in data['random_sample']:
                sample['tokens'] = tokenizer.encode(''.join(sample['tokens']))
            for sample_list in data['random_sample_by_quantile']:
                for sample in sample_list:
                    sample['tokens'] = tokenizer.encode(''.join(sample['tokens']))
            for sample in data['most_positive_activation_records']:
                sample['tokens'] = tokenizer.encode(''.join(sample['tokens']))

    with open(data_dir, 'w') as f:
        json.dump(data, f, separators=(',', ':'))

def download_and_process(layer, neuron, dir="../data"):
    """
    Download data from Azure blob storage and process data from neuron-viewer json format to a more efficient token-encoded format.
    """    

    # Check if data exists
    if os.path.exists(f"{dir}/{neuron}.json"):
        print(f"Data already exists for layer {layer}, neuron {neuron}.")
        return
    
    # Download data from Azure blob storage
    download_data(layer, neuron, dir)
    
    # Process data
    data_dir = f"{dir}/{neuron}.json"
    data_processing(data_dir)

def download_and_process_all(layers = 48, neurons = 6400, model = "gpt2-xl"):
    """
    Download data from Azure blob storage and process data from neuron-viewer json format to a more efficient token-encoded format.
    """    
    
    # Download data from Azure blob storage and process data with parallelization
    Parallel(n_jobs=num_cores)(delayed(download_and_process)(layer, neuron, f"../data/{model}/{layer}") for layer in range(layers) for neuron in range(neurons))
# Out:
# Number of cores: 10

# %%
# %%capture

download_and_process_all()
# Out:
# Data already exists for layer 0, neuron 0.
# Data already exists for layer 0, neuron 5.
# Data already exists for layer 0, neuron 1.
# Data already exists for layer 0, neuron 2.
# Data already exists for layer 0, neuron 3.
# 0 8
# Data already exists for layer 0, neuron 4.
# Data already exists for layer 0, neuron 10.
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 6
# 0 11
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 12
# 0 7
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 60312c5a-0ba9-eb4b-4330-11f594eec5ea has started
# Log file is located at: /Users/esben/.azcopy/60312c5a-0ba9-eb4b-4330-11f594eec5ea.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job bc780a8b-e205-8343-7c90-5c629c68eb24 has started
# Log file is located at: /Users/esben/.azcopy/bc780a8b-e205-8343-7c90-5c629c68eb24.log
#
#
# Job 79c12819-7908-c84b-6e95-da57fecb8bd5 has started
# Log file is located at: /Users/esben/.azcopy/79c12819-7908-c84b-6e95-da57fecb8bd5.log
#
# 0 15
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 16
# 0 9
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9327
#
#
# Job 60312c5a-0ba9-eb4b-4330-11f594eec5ea summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234034
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job bee1b233-c85d-9b40-642c-b143def6b9f3 has started
# Log file is located at: /Users/esben/.azcopy/bee1b233-c85d-9b40-642c-b143def6b9f3.log
#
#
# Job edc1ea45-671f-d74a-7150-0be13875f566 has started
# Log file is located at: /Users/esben/.azcopy/edc1ea45-671f-d74a-7150-0be13875f566.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9351
#
#
# Job bc780a8b-e205-8343-7c90-5c629c68eb24 summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 235018
# Final Job Status: Completed
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9345
#
#
# Job 79c12819-7908-c84b-6e95-da57fecb8bd5 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233927
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 0 13
#
# Job b4d72b84-ad62-9d4b-4fe4-5b59a157b092 has started
# Log file is located at: /Users/esben/.azcopy/b4d72b84-ad62-9d4b-4fe4-5b59a157b092.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 0 14
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job dc7cfbbf-3483-324a-4c93-198415f28ddf has started
# Log file is located at: /Users/esben/.azcopy/dc7cfbbf-3483-324a-4c93-198415f28ddf.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.938
#
#
# Job bee1b233-c85d-9b40-642c-b143def6b9f3 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234782
# Final Job Status: Completed
#
#
# Job f6796034-4def-9248-6014-9796b75cd673 has started
# Log file is located at: /Users/esben/.azcopy/f6796034-4def-9248-6014-9796b75cd673.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9328
#
#
# Job edc1ea45-671f-d74a-7150-0be13875f566 summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234242
# Final Job Status: Completed
#
# 0 17
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 18
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9169
#
#
# Job b4d72b84-ad62-9d4b-4fe4-5b59a157b092 summary
# Elapsed Time (Minutes): 0.0341
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234284
# Final Job Status: Completed
#
# 0 19
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9271
#
#
# Job dc7cfbbf-3483-324a-4c93-198415f28ddf summary
# Elapsed Time (Minutes): 0.0338
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234930
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
#
# Job b891b2aa-cf6b-1c48-7716-16cbd24c907a has started
# Log file is located at: /Users/esben/.azcopy/b891b2aa-cf6b-1c48-7716-16cbd24c907a.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9382
#
#
# Job f6796034-4def-9248-6014-9796b75cd673 summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 235434
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 0671a3f5-2f21-f54a-7532-c8476651b735 has started
# Log file is located at: /Users/esben/.azcopy/0671a3f5-2f21-f54a-7532-c8476651b735.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 0 20
#
# Job d9dcb1f8-f081-8942-78c3-e01f08fc1fb6 has started
# Log file is located at: /Users/esben/.azcopy/d9dcb1f8-f081-8942-78c3-e01f08fc1fb6.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 21
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.924
#
#
# Job b891b2aa-cf6b-1c48-7716-16cbd24c907a summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 231947
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job c17ca384-a809-c44c-470e-a75fae5521a4 has started
# Log file is located at: /Users/esben/.azcopy/c17ca384-a809-c44c-470e-a75fae5521a4.log
#
#
# Job 0cc52706-aef9-0649-4993-375350ff0c70 has started
# Log file is located at: /Users/esben/.azcopy/0cc52706-aef9-0649-4993-375350ff0c70.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9331
#
#
# Job 0671a3f5-2f21-f54a-7532-c8476651b735 summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234554
# Final Job Status: Completed
#
# 0 22
# 0 23
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 24
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9305
#
#
# Job d9dcb1f8-f081-8942-78c3-e01f08fc1fb6 summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234203
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 1c23b227-b199-6043-51eb-c1b988e2e6ae has started
# Log file is located at: /Users/esben/.azcopy/1c23b227-b199-6043-51eb-c1b988e2e6ae.log
#
# 0 25
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9462
#
#
# Job c17ca384-a809-c44c-470e-a75fae5521a4 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 236771
# Final Job Status: Completed
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9203
#
#
# Job 0cc52706-aef9-0649-4993-375350ff0c70 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 230807
# Final Job Status: Completed
#
#
# Job 260634e2-ecbc-164e-7464-3725e81c318f has started
# Log file is located at: /Users/esben/.azcopy/260634e2-ecbc-164e-7464-3725e81c318f.log
#
# 0 26
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 0be82c19-d3d9-2c45-64ea-11aac1264c7a has started
# Log file is located at: /Users/esben/.azcopy/0be82c19-d3d9-2c45-64ea-11aac1264c7a.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job b4f5e413-d157-de48-6436-1cd923700459 has started
# Log file is located at: /Users/esben/.azcopy/b4f5e413-d157-de48-6436-1cd923700459.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 0 27
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.933
#
#
# Job 1c23b227-b199-6043-51eb-c1b988e2e6ae summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234640
# Final Job Status: Completed
#
#
# Job afffa497-dcd1-5944-561c-5ab131dbea5d has started
# Log file is located at: /Users/esben/.azcopy/afffa497-dcd1-5944-561c-5ab131dbea5d.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9339
#
#
# Job 260634e2-ecbc-164e-7464-3725e81c318f summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234232
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job ed43e056-3a47-4b41-4a6e-b563caf88b3d has started
# Log file is located at: /Users/esben/.azcopy/ed43e056-3a47-4b41-4a6e-b563caf88b3d.log
#
# 0 29
# 0 28
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9327
#
#
# Job 0be82c19-d3d9-2c45-64ea-11aac1264c7a summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233609
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.936
#
#
# Job b4f5e413-d157-de48-6436-1cd923700459 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234768
# Final Job Status: Completed
#
#
# Job 99858404-576a-8940-7f10-30644cbe84c4 has started
# Log file is located at: /Users/esben/.azcopy/99858404-576a-8940-7f10-30644cbe84c4.log
#
# 0 30
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9165
#
#
# Job afffa497-dcd1-5944-561c-5ab131dbea5d summary
# Elapsed Time (Minutes): 0.0337
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 231906
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 31
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.941
#
#
# Job ed43e056-3a47-4b41-4a6e-b563caf88b3d summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 235864
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job f7908efb-d86e-3c4e-57d0-66b8aa314411 has started
# Log file is located at: /Users/esben/.azcopy/f7908efb-d86e-3c4e-57d0-66b8aa314411.log
#
# 0 32
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Scanning...
# INFO: Autologin not specified.
#
# Job 41b874e6-2028-fe42-5355-98e8b485a322 has started
# Log file is located at: /Users/esben/.azcopy/41b874e6-2028-fe42-5355-98e8b485a322.log
#
#
# Job 2ff9c65d-df42-744b-67b0-017ff697a14b has started
# Log file is located at: /Users/esben/.azcopy/2ff9c65d-df42-744b-67b0-017ff697a14b.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9373
#
#
# Job 99858404-576a-8940-7f10-30644cbe84c4 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234650
# Final Job Status: Completed
#
# 0 33
# 0 34
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 35
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job fdc3b5ac-5efe-9c48-790c-ec71f627f13f has started
# Log file is located at: /Users/esben/.azcopy/fdc3b5ac-5efe-9c48-790c-ec71f627f13f.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.93
#
#
# Job f7908efb-d86e-3c4e-57d0-66b8aa314411 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 232776
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9229
#
#
# Job 41b874e6-2028-fe42-5355-98e8b485a322 summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 232668
# Final Job Status: Completed
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9114
#
#
# Job 2ff9c65d-df42-744b-67b0-017ff697a14b summary
# Elapsed Time (Minutes): 0.0339
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 231582
# Final Job Status: Completed
#
#
# Job 126b3e38-c9f4-3d41-7c15-33ae3b6b89c4 has started
# Log file is located at: /Users/esben/.azcopy/126b3e38-c9f4-3d41-7c15-33ae3b6b89c4.log
#
# 0 36
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job f5b462a9-3ebd-6148-667c-ab818e69b6a3 has started
# Log file is located at: /Users/esben/.azcopy/f5b462a9-3ebd-6148-667c-ab818e69b6a3.log
#
#
# Job a4199164-8e08-7a43-72a7-a3181e32bb65 has started
# Log file is located at: /Users/esben/.azcopy/a4199164-8e08-7a43-72a7-a3181e32bb65.log
#
# 100.0 %, 0 Done, 0 Failed, 1 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9248
# Job e2f48ef7-000c-794c-718c-ec36a7a2e43a has started
# Log file is located at: /Users/esben/.azcopy/e2f48ef7-000c-794c-718c-ec36a7a2e43a.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9244
#
#
# Job 126b3e38-c9f4-3d41-7c15-33ae3b6b89c4 summary
# Elapsed Time (Minutes): 0.0341
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 236587
# Final Job Status: Completed
#
#
# Job a02f9451-bfb0-8646-4c85-0543c812ce1b has started
# Log file is located at: /Users/esben/.azcopy/a02f9451-bfb0-8646-4c85-0543c812ce1b.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9337
#
#
# Job f5b462a9-3ebd-6148-667c-ab818e69b6a3 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233704
# Final Job Status: Completed
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total,
#
#
# Job fdc3b5ac-5efe-9c48-790c-ec71f627f13f summary
# Elapsed Time (Minutes): 0.0668
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 232334
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9196
#
#
# Job e2f48ef7-000c-794c-718c-ec36a7a2e43a summary
# Elapsed Time (Minutes): 0.034
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234528
# Final Job Status: Completed
#
#
# Job 263ea62f-38b0-2141-5b8a-50fb99c7b94a has started
# Log file is located at: /Users/esben/.azcopy/263ea62f-38b0-2141-5b8a-50fb99c7b94a.log
#
# 0 37
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.921
#
#
# Job a02f9451-bfb0-8646-4c85-0543c812ce1b summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 232278
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total,
#
#
# Job a4199164-8e08-7a43-72a7-a3181e32bb65 summary
# Elapsed Time (Minutes): 0.067
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 235573
# Final Job Status: Completed
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9227
#
#
# Job 263ea62f-38b0-2141-5b8a-50fb99c7b94a summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 232672
# Final Job Status: Completed
#
# 0 38
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 39
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Scanning...
# INFO: Autologin not specified.
#
# Job aaafb60f-c910-484d-6a3d-e57b0c37e290 has started
# Log file is located at: /Users/esben/.azcopy/aaafb60f-c910-484d-6a3d-e57b0c37e290.log
#
# 0 40
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 42
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 0 41
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9237
#
#
# Job aaafb60f-c910-484d-6a3d-e57b0c37e290 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 231429
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job a7c850eb-8ded-1c45-5f51-39330cfef706 has started
# Log file is located at: /Users/esben/.azcopy/a7c850eb-8ded-1c45-5f51-39330cfef706.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Scanning...
# INFO: Autologin not specified.
#
# Job d5574283-cca2-7841-79fd-ea9f6a23c1a5 has started
# Log file is located at: /Users/esben/.azcopy/d5574283-cca2-7841-79fd-ea9f6a23c1a5.log
#
# 0 43
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 6995b28d-d737-be4e-6a2b-953a063bca4b has started
# Log file is located at: /Users/esben/.azcopy/6995b28d-d737-be4e-6a2b-953a063bca4b.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9268
#
#
# Job a7c850eb-8ded-1c45-5f51-39330cfef706 summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233747
# Final Job Status: Completed
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.944
#
#
# Job d5574283-cca2-7841-79fd-ea9f6a23c1a5 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 236383
# Final Job Status: Completed
#
# 0 44
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 6337b305-3c48-ff43-5e54-472b476a2a6c has started
# Log file is located at: /Users/esben/.azcopy/6337b305-3c48-ff43-5e54-472b476a2a6c.log
#
#
# Job ee510136-6c36-f34a-7e04-2c9bbd86f2cf has started
# Log file is located at: /Users/esben/.azcopy/ee510136-6c36-f34a-7e04-2c9bbd86f2cf.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 45
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9379
#
#
# Job 6995b28d-d737-be4e-6a2b-953a063bca4b summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 235605
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 0 46
#
# Job ed12b062-6796-6441-5268-34931ffa424b has started
# Log file is located at: /Users/esben/.azcopy/ed12b062-6796-6441-5268-34931ffa424b.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9168
#
#
# Job 6337b305-3c48-ff43-5e54-472b476a2a6c summary
# Elapsed Time (Minutes): 0.0338
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 232485
# Final Job Status: Completed
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9049
#
#
# Job ee510136-6c36-f34a-7e04-2c9bbd86f2cf summary
# Elapsed Time (Minutes): 0.0344
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233744
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 7fb2fd41-310e-ac4e-6138-e05bbad1b171 has started
# Log file is located at: /Users/esben/.azcopy/7fb2fd41-310e-ac4e-6138-e05bbad1b171.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9249
#
#
# Job ed12b062-6796-6441-5268-34931ffa424b summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233236
# Final Job Status: Completed
#
#
# Job 957fc41e-bdc3-8f40-4f9e-b93854966d4d has started
# Log file is located at: /Users/esben/.azcopy/957fc41e-bdc3-8f40-4f9e-b93854966d4d.log
#
# 0 47
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9298
#
#
# Job 7fb2fd41-310e-ac4e-6138-e05bbad1b171 summary
# Elapsed Time (Minutes): 0.0338
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 235621
# Final Job Status: Completed
#
#
# Job 0216c124-65a6-274f-5b0d-42bfe515a82f has started
# Log file is located at: /Users/esben/.azcopy/0216c124-65a6-274f-5b0d-42bfe515a82f.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.8986
#
#
# Job 957fc41e-bdc3-8f40-4f9e-b93854966d4d summary
# Elapsed Time (Minutes): 0.035
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 235811
# Final Job Status: Completed
#
# 0 48
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 0 49
# INFO: Scanning...
# INFO: Autologin not specified.
#
# Job 56c9144a-eb9d-fa4b-72bf-e16d8c046025 has started
# Log file is located at: /Users/esben/.azcopy/56c9144a-eb9d-fa4b-72bf-e16d8c046025.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9101
#
#
# Job 0216c124-65a6-274f-5b0d-42bfe515a82f summary
# Elapsed Time (Minutes): 0.0345
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 235692
# Final Job Status: Completed
#
# 0 50
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 51
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9327
#
#
# Job 56c9144a-eb9d-fa4b-72bf-e16d8c046025 summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234142
# Final Job Status: Completed
#
#
# Job b5dbb248-8ca8-3d48-4146-10ed0f909915 has started
# Log file is located at: /Users/esben/.azcopy/b5dbb248-8ca8-3d48-4146-10ed0f909915.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 52
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 740ee9fe-1231-3a41-6ba6-1892a77675b0 has started
# Log file is located at: /Users/esben/.azcopy/740ee9fe-1231-3a41-6ba6-1892a77675b0.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 6f7c6246-41f4-1641-4bc7-21f98b7d9ea9 has started
# Log file is located at: /Users/esben/.azcopy/6f7c6246-41f4-1641-4bc7-21f98b7d9ea9.log
#
# 0 53
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9347
#
#
# Job b5dbb248-8ca8-3d48-4146-10ed0f909915 summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 235433
# Final Job Status: Completed
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9321
#
#
# Job 740ee9fe-1231-3a41-6ba6-1892a77675b0 summary
# Elapsed Time (Minutes): 0.0339
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 236857
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 79bb408e-1b70-2a4f-74bf-9d0782bdd7df has started
# Log file is located at: /Users/esben/.azcopy/79bb408e-1b70-2a4f-74bf-9d0782bdd7df.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9196
#
#
# Job 6f7c6246-41f4-1641-4bc7-21f98b7d9ea9 summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 231392
# Final Job Status: Completed
#
#
# Job 26477d5e-e1e6-1e47-5382-a507194a03ba has started
# Log file is located at: /Users/esben/.azcopy/26477d5e-e1e6-1e47-5382-a507194a03ba.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 0 54
#
# Job c24f1cde-ad2b-ba40-7d40-440b4e5920c5 has started
# Log file is located at: /Users/esben/.azcopy/c24f1cde-ad2b-ba40-7d40-440b4e5920c5.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9291
#
#
# Job 79bb408e-1b70-2a4f-74bf-9d0782bdd7df summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233703
# Final Job Status: Completed
#
# 0 55
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9414
#
#
# Job 26477d5e-e1e6-1e47-5382-a507194a03ba summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 236915
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 56
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9307
#
#
# Job c24f1cde-ad2b-ba40-7d40-440b4e5920c5 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233213
# Final Job Status: Completed
#
# 0 57
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 0 58
#
# Job 9b0a5354-477f-ea45-70de-02fe4268c223 has started
# Log file is located at: /Users/esben/.azcopy/9b0a5354-477f-ea45-70de-02fe4268c223.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 59
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 3462f9d6-e3ee-0040-6ee5-583b95a4815c has started
# Log file is located at: /Users/esben/.azcopy/3462f9d6-e3ee-0040-6ee5-583b95a4815c.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
#
# Job f1b41ef0-5062-ab49-5d63-4a1516f24f38 has started
# Log file is located at: /Users/esben/.azcopy/f1b41ef0-5062-ab49-5d63-4a1516f24f38.log
#
# 0 60
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job f52aefbb-fcd9-574b-7fbb-07dbb8eab665 has started
# Log file is located at: /Users/esben/.azcopy/f52aefbb-fcd9-574b-7fbb-07dbb8eab665.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9444
#
#
# Job 9b0a5354-477f-ea45-70de-02fe4268c223 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 236429
# Final Job Status: Completed
#
# 0 61
# 0 62
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9147
#
#
# Job 3462f9d6-e3ee-0040-6ee5-583b95a4815c summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 229988
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9345
#
#
# Job f1b41ef0-5062-ab49-5d63-4a1516f24f38 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234386
# Final Job Status: Completed
#
#
# Job 25b503d0-9d47-e94e-5ccc-3c9c473309f2 has started
# Log file is located at: /Users/esben/.azcopy/25b503d0-9d47-e94e-5ccc-3c9c473309f2.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 36ee8fcc-3c88-184c-50bd-a1445b0fb5e5 has started
# Log file is located at: /Users/esben/.azcopy/36ee8fcc-3c88-184c-50bd-a1445b0fb5e5.log
#
# 0 63INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9243
#
#
# Job f52aefbb-fcd9-574b-7fbb-07dbb8eab665 summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 232863
# Final Job Status: Completed
#
#
# Job b78ec12f-c7a5-db42-40ab-c1d90ea21b32 has started
# Log file is located at: /Users/esben/.azcopy/b78ec12f-c7a5-db42-40ab-c1d90ea21b32.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9295
#
#
# Job 25b503d0-9d47-e94e-5ccc-3c9c473309f2 summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234099
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 0681db0a-8ed2-4545-40db-a213e67539c9 has started
# Log file is located at: /Users/esben/.azcopy/0681db0a-8ed2-4545-40db-a213e67539c9.log
#
#
# Job 40ce84d1-90be-3748-77fb-6497c858c584 has started
# Log file is located at: /Users/esben/.azcopy/40ce84d1-90be-3748-77fb-6497c858c584.log
#
# ...
#
# Job 3cde488d-a289-524a-6b7f-297549833e81 has started
# Log file is located at: /Users/esben/.azcopy/3cde488d-a289-524a-6b7f-297549833e81.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 91
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9282
#
#
# Job 840bef0b-4c75-3948-6b6a-11b251c790b8 summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233570
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.8601
#
#
# Job 336e206f-1a46-8747-4a06-efe284467667 summary
# Elapsed Time (Minutes): 0.0364
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234996
# Final Job Status: Completed
#
# 0 92
# INFO: Scanning...
# INFO: Autologin not specified.
#
# Job 429a1c05-d918-bc40-7e3d-497221e2d366 has started
# Log file is located at: /Users/esben/.azcopy/429a1c05-d918-bc40-7e3d-497221e2d366.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9325
#
#
# Job 420b1c5e-71e3-1247-6130-f428426f6d4f summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233772
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job afc2861c-3e12-5c4e-72e7-0a8a2ead623e has started
# Log file is located at: /Users/esben/.azcopy/afc2861c-3e12-5c4e-72e7-0a8a2ead623e.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9207
#
#
# Job 3cde488d-a289-524a-6b7f-297549833e81 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 230670
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job f663fc0a-df44-c440-4293-08e234f58abe has started
# Log file is located at: /Users/esben/.azcopy/f663fc0a-df44-c440-4293-08e234f58abe.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 0 93
# INFO: Scanning...
# INFO: Autologin not specified.
#
# Job c1dd04c6-393e-0941-5e9a-260392e383cc has started
# Log file is located at: /Users/esben/.azcopy/c1dd04c6-393e-0941-5e9a-260392e383cc.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9495
#
#
# Job 429a1c05-d918-bc40-7e3d-497221e2d366 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 237588
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job f705c5bd-5b91-584b-6507-85d3addcbb95 has started
# Log file is located at: /Users/esben/.azcopy/f705c5bd-5b91-584b-6507-85d3addcbb95.log
#
# 0 94
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9241
#
#
# Job afc2861c-3e12-5c4e-72e7-0a8a2ead623e summary
# Elapsed Time (Minutes): 0.0338
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234055
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 95
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9179
#
#
# Job f663fc0a-df44-c440-4293-08e234f58abe summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 229840
# Final Job Status: Completed
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.8823
#
#
# Job c1dd04c6-393e-0941-5e9a-260392e383cc summary
# Elapsed Time (Minutes): 0.0353
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233637
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9433
#
#
# Job f705c5bd-5b91-584b-6507-85d3addcbb95 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 236439
# Final Job Status: Completed
#
#
# Job f1c8c9e0-0361-0e4c-4ed4-7a782332087c has started
# Log file is located at: /Users/esben/.azcopy/f1c8c9e0-0361-0e4c-4ed4-7a782332087c.log
#
# 0 96
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 0 97
# INFO: Scanning...
# INFO: Autologin not specified.
#
# Job ecfa1f33-2ffc-9d4e-4756-2a4f12290867 has started
# Log file is located at: /Users/esben/.azcopy/ecfa1f33-2ffc-9d4e-4756-2a4f12290867.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 3e43b7d5-7d8f-d24f-568b-d9a86ec8b30e has started
# Log file is located at: /Users/esben/.azcopy/3e43b7d5-7d8f-d24f-568b-d9a86ec8b30e.log
#
# 0 98
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9312
#
#
# Job f1c8c9e0-0361-0e4c-4ed4-7a782332087c summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233174
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 99
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 100
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job b5006ef5-c5f1-3e46-5087-989f867aee9b has started
# Log file is located at: /Users/esben/.azcopy/b5006ef5-c5f1-3e46-5087-989f867aee9b.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9147
#
#
# Job ecfa1f33-2ffc-9d4e-4756-2a4f12290867 summary
# Elapsed Time (Minutes): 0.0343
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234999
# Final Job Status: Completed
#
#
# Job c0a5fac0-353d-2c41-483b-8371d42d1dde has started
# Log file is located at: /Users/esben/.azcopy/c0a5fac0-353d-2c41-483b-8371d42d1dde.log
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 101
# 0 102
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9423
#
#
# Job 3e43b7d5-7d8f-d24f-568b-d9a86ec8b30e summary
# Elapsed Time (Minutes): 0.0333
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 235653
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9048
#
#
# Job b5006ef5-c5f1-3e46-5087-989f867aee9b summary
# Elapsed Time (Minutes): 0.0344
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233683
# Final Job Status: Completed
#
#
# Job 15633502-9e38-d346-6484-adc0742d5601 has started
# Log file is located at: /Users/esben/.azcopy/15633502-9e38-d346-6484-adc0742d5601.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.933
#
#
# Job c0a5fac0-353d-2c41-483b-8371d42d1dde summary
# Elapsed Time (Minutes): 0.0338
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 236679
# Final Job Status: Completed
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 61898dfd-0633-ec4d-4368-bda1afa628a8 has started
# Log file is located at: /Users/esben/.azcopy/61898dfd-0633-ec4d-4368-bda1afa628a8.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 281d9ee6-954a-314e-7fbe-04d5e26c21de has started
# Log file is located at: /Users/esben/.azcopy/281d9ee6-954a-314e-7fbe-04d5e26c21de.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job d78af45e-2498-9b47-438d-27285202d27e has started
# Log file is located at: /Users/esben/.azcopy/d78af45e-2498-9b47-438d-27285202d27e.log
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9379
#
#
# Job 15633502-9e38-d346-6484-adc0742d5601 summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234640
# Final Job Status: Completed
#
#
# Job fc293a5e-86d0-7147-7d69-aa17daf3b5ee has started
# Log file is located at: /Users/esben/.azcopy/fc293a5e-86d0-7147-7d69-aa17daf3b5ee.log
#
# 0 103
# INFO: Scanning...
# INFO: Autologin not specified.
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.933
#
#
# Job 61898dfd-0633-ec4d-4368-bda1afa628a8 summary
# Elapsed Time (Minutes): 0.0337
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 235716
# Final Job Status: Completed
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9349
#
#
# Job 281d9ee6-954a-314e-7fbe-04d5e26c21de summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 234566
# Final Job Status: Completed
#
# 0 104
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9257
#
#
# Job d78af45e-2498-9b47-438d-27285202d27e summary
# Elapsed Time (Minutes): 0.0336
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 233549
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 105
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.928
#
#
# Job fc293a5e-86d0-7147-7d69-aa17daf3b5ee summary
# Elapsed Time (Minutes): 0.0335
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 232820
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 106
# INFO: Scanning...
# INFO: Autologin not specified.
# 0 107
# INFO: Scanning...
# INFO: Autologin not specified.

# %%
current_dir = f"{1}"
current_data = f"{1}.json"

for l in range(1, 48):
    current_dir = f"../data/{l}"
    for n in range(0, 6400):
        current_data = f"../data/{l}/{n}.json"
        download_data(l,n, current_dir)
        data_processing(current_data)
# Out:
# 2 6399
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job face1ccc-4521-1948-752a-6dd10e8d33fb has started
# Log file is located at: /Users/esben/.azcopy/face1ccc-4521-1948-752a-6dd10e8d33fb.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 0.9455
#
#
# Job face1ccc-4521-1948-752a-6dd10e8d33fb summary
# Elapsed Time (Minutes): 0.0334
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 236547
# Final Job Status: Completed
